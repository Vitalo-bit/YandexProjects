# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Нияз, привет!</b>
#
# Меня зовут Евгений Головин, я буду ревьюером твоего проекта. Если ты не против, то предлагаю построить наше общение на "ты" ;) Если удобнее на "вы", то нет проблем, только скажи об этом.
#
# В ходе работы я оставил тебе комментарии <font color='green'>зеленого</font>, <font color='gold'>желтого</font> и <font color='red'>красного</font> цветов. Сейчас объясню, что они значат:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Решение на этом шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Решение на этом шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  Решение на этом шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
# Увидев мой комментарий, не удаляй его, он будет очень полезен в случае повторной проверки работы :)
#
# <div class="alert alert-info">
# <b>А свой помечай вот так, чтобы я его не потерял ;)</b>
# </div>
#
# На мои комменатрии можно и нужно реагировать, только делать это стоит так, чтобы твои и мои комменты не смешались: выделяй свои цветами, сильно отличающимися от моих.
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе аналитиком. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>  А давай начнем с введения?

# %% [markdown]
# Нам предстоит исследовать информацию о фильмах, которые находились в прокате с 2010 по 2019 года. Мы выполним предобработку данных, а затем исследуем их и сделаем выводы. Изучим сумму сборов по годам, найдём самую выгодную категорию фильмов, посмотрим сколько в среднем собирают фильмы.
#
# Цели:
# 1. Изучить, как менялась динамика проката по годам.
# 2. Определить, влияет ли возрастное ограничение аудитории («6+», «12+», «16+», «18+» и т. д.) на сборы фильма в прокате в период с 2015 по 2019 год.
# 3. Исследовать фильмы, которые получили государственную поддержку. Изучить их сборы, окупаемость, рейтинг, режиссёров и основные жанры.
#
# План:
# 1. Объединить датафреймы
# 2. Выполнить предобработку
# 3. Исследовать данные
# 4. Сделать вывод
#
# Описание данных:
# * title — название фильма;
# * puNumber — номер прокатного удостоверения;
# * show_start_date — дата премьеры фильма;
# * type — тип фильма;
# * film_studio — студия-производитель;
# * production_country — страна-производитель;
# * director — режиссёр;
# * producer — продюсер;
# * age_restriction — возрастная категория;
# * refundable_support — объём возвратных средств государственной поддержки;
# * nonrefundable_support — объём невозвратных средств государственной поддержки;
# * financing_source — источник государственного финансирования;
# * budget — общий бюджет фильма;
# * ratings — рейтинг фильма на КиноПоиске;
# * genres — жанр фильма.
# * puNumber — номер прокатного удостоверения;
# * box_office — сборы в рублях.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Замечательно) Было бы супер добавить цель, план работы и описание данных?)

# %% [markdown]
# <div class="alert alert-info">
# Сделано.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v4 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Идеально)

# %% [markdown]
# ## Исследование данных о российском кинопрокате

# %% [markdown]
# ### Шаг 1. Откройте файлы с данными и объедините их в один датафрейм.
#
# Объедините данные таким образом, чтобы все объекты из датасета `mkrf_movies` обязательно вошли в получившийся датафрейм.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_0" aria-expanded="false" aria-controls="collapseHint_0">Подсказка</button>
#         </div>
#         <div id="collapseHint_0" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Обратите внимание на тип данных столбца, по которому будете соединять датафреймы. Тип данных этих столбцов должен быть одинаковым в обоих датафреймах.
#             </div>
#         </div>
#     </div>
# </div>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import warnings


def data_swap(string):
    if string == 'нет':
        string = None
    else:
        string = int(string)
    return string


data_first = pd.read_csv('/datasets/mkrf_movies.csv', sep=',')
data_second = pd.read_csv('/datasets/mkrf_shows.csv', sep=',')
print(data_first.info())
display(data_first)
print(data_second.info())
display(data_second)
data_first['puNumber'] = data_first['puNumber'].apply(data_swap)
data_first = data_first.dropna(subset=['puNumber'])
print(data_first.info())
display(data_first)
data_first['puNumber'] = data_first['puNumber'].apply(data_swap)
print(data_first.info())
display(data_first)
data = data_first.merge(data_second, on='puNumber', how='left')
print(data.info())
display(data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7486 entries, 0 to 7485
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7486 non-null   object
#  2   show_start_date        7486 non-null   object
#  3   type                   7486 non-null   object
#  4   film_studio            7468 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7477 non-null   object
#  7   producer               6918 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   object
# ...

# %% [markdown]
# Для склейки двух таблиц необходимо чтобы столбец по которому мы склеиваем был одного типа данных. Изучив содержимое таблиц я заметил, что тип данных в столбце puNumber - object. Это значит что там содержатся данные различных типов. Я изучил этот столбец и заметил что там есть строка "нет". Я применил функцию data_swap и удалил все значения с "нет". После чего я убедился в типе данных и склеил обе таблицы.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Хорошо, молодец) Только давай сначала посмотрим с какими данными работаем, а потом проверим получилось ли верно объединить датафреймы

# %% [markdown]
# <div class="alert alert-info">
# Применил метод info к датафрейму до обработки столбца и после обработки столбца. Видно что даже после удаления None объектов тип остался float, поэтому я повторно применил к нему свою функцию, после чего столбец стал типа int.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>А на датафрейм посмотрим?)

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v3 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Через display()? Грустно, что пропускаешь замечания:(

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v4 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Молодец!

# %% [markdown]
# ### Шаг 2. Предобработка данных

# %% [markdown]
# #### Шаг 2.1. Проверьте типы данных
#
# - Проверьте типы данных в датафрейме и преобразуйте их там, где это необходимо.

# %%
def age_norm(age):
    age = age.split("+")
    age = age[0][1:]
    return age


def title_check(name):
    return str(name)


def rating_norm(rating):
    if isinstance(rating, str):
        if '%' in rating:
            rating = int(rating[:-1]) / 10
    else:
        rating = float(rating)
    return rating

display(data)
data['show_start_date'] = pd.to_datetime(data['show_start_date'])
data['title'] = data['title'].apply(title_check)
data['ratings'] = data['ratings'].apply(rating_norm)
data['ratings'] = pd.to_numeric(data['ratings'], errors='coerce')
data['age_restriction'] = data['age_restriction'].apply(age_norm)
display(data)
# Out:
#                                              title   puNumber  \
# 0                                 Открытый простор  221048915
# 1                             Особо важное задание  111013716
# 2                                     Особо опасен  221038416
# 3                                     Особо опасен  221026916
# 4                                     Особо опасен  221030815
# ...                                            ...        ...
# 7480     Сад художника: Американский импрессионизм  126008019
# 7481                               Звериная ярость  121037819
# 7482     Щенячий патруль: Скорей спешим на помощь!  124010819
# 7483      Машины песенки. Серия "Испанские мотивы"  124010619
# 7484  Машины песенки. Серия "Когда цветут кактусы"  124010719
#
#                show_start_date             type  \
# 0     2015-11-27T12:00:00.000Z   Художественный
# 1     2016-09-13T12:00:00.000Z   Художественный
# 2     2016-10-10T12:00:00.000Z   Художественный
# ...

# %% [markdown]
# Я перевёл столбец "show_start_date" в тип данных datetime для удобства в последующем использовании. Так же я перевёл в строки названия и упростил типизацию возраста. Также я обратил внимание на систему рейтингов и перевёл процентную систему оценивания в десятибалльную.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>  Тоже самое) Мало просто кода и вывода, необходимо проверить, продемонстрировать) Откуда ты знаешь, что тип данных смнился?)

# %% [markdown]
# <div class="alert alert-info">
# Также применил метод info перед и после обработки. Вывел таблицу для понимания изменился ли датафрейм. Если столбец содержит значения типа None то столбец в любом случае будет типа object, поэтому на текущем этапе я не вижу в этом проблемы.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Отлично) только print() работал для списков и словарей, для датафрейм лучше использовать display()

# %% [markdown]
# <div class="alert alert-info">
# Сделано
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v3 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Лайк)

# %% [markdown]
# #### Шаг 2.2. Изучите пропуски в датафрейме
#
# - Объясните, почему заполнили пропуски определённым образом или почему не стали этого делать.

# %%
print(data.isna().sum())
data = data.dropna(subset=['film_studio'])
data = data.dropna(subset=['production_country'])
data = data.dropna(subset=['director'])
data.loc[data['producer'].isna(), ['producer']] = data['director']
print(data.isna().sum().sort_values())
# Out:
# title                       0
# puNumber                    0
# show_start_date             0
# type                        0
# film_studio                18
# production_country          2
# director                    9
# producer                  568
# age_restriction             0
# refundable_support       7153
# nonrefundable_support    7153
# budget                   7153
# financing_source         7153
# ratings                   966
# genres                    975
# box_office               4327
# dtype: int64
# title                       0
# puNumber                    0
# show_start_date             0
# type                        0
# film_studio                 0
# production_country          0
# director                    0
# producer                    0
# age_restriction             0
# ratings                   947
# genres                    956
# box_office               4303
# refundable_support       7126
# nonrefundable_support    7126
# ...

# %% [markdown]
# Я изучил пропуски и удалил незначительные, которые не повлияют на датасет. Также я заменил пропуски в столбце с продюссером на режисёров. Остальные пропуски были слишком значительными и правила для их заполнения нет. Например пропуски в столбцах support очевидны - минкультуры не будет поддерживать иностранные фильмы)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>  Хорошо, согласен с тобой) Но давай выведем информацию о  количетве пропусков?

# %% [markdown]
# <div class="alert alert-info">Применил методы .isna().sum() к датафрейму до и после обработки. Виден результат.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Супер! было бы круто отсортировать)

# %% [markdown]
# <div class="alert alert-info">
# Сделано
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v3 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> топ)

# %% [markdown]
# #### Шаг 2.3. Изучите дубликаты в датафрейме
# - Проверьте, есть ли в данных дубликаты. Опишите причины, которые могли повлиять на появление дублей.

# %%
print(data['title'].value_counts())
display(data.loc[data['title'] == "Анализируй то!"])
display(data.loc[data['title'] == "Анализируй это!"])
data = data.drop_duplicates(subset=['puNumber'])
# Out:
# День святого Валентина_                             5
# Не брать живым /По книге Раджива Чандрасекарана/    4
# Дитя тьмы                                           4
# Лузеры                                              4
# Красавчик-2                                         4
#                                                    ..
# ЗЛО                                                 1
# Три лица                                            1
# Время отдыха с субботы до понедельника              1
# Город Ангелов                                       1
# Капитан семи морей                                  1
# Name: title, Length: 6745, dtype: int64
#                title   puNumber           show_start_date            type  \
# 5067  Анализируй то!  221054410 2010-05-25 12:00:00+00:00  Художественный
#
#                                             film_studio production_country  \
# 5067  Уорнер Бразерс, Виллидж Роадшоу Пикчерз, Эн-Пи...                США
#
# ...

# %% [markdown]
# Я заметил дубликаты в прокатных удостоверениях. Удалил их, возможно они возникли случайно. Дубликаты с названиями я оставил, т.к. их прокатные удостоверения различны и возможно эти фильмы проигрывали в различных кинотеатрах, что в свою очередь отразится на сумме сборов.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>  Рассмотрим что за дубликаты?) Может это вовсе и не они?) А какие столбцы у нас еще уникальны? Где может повстречать дублирующие значения?

# %% [markdown]
# <div class="alert alert-info">Не совсем понимаю о чём идёт речь. По-сути дубли можно повстречать везде, критичны только дубли в названиях и прокатных удостоверениях, но по этому поводу я уже высказался, дубли в прокатных удостоверениях я удалил. То что совпадают бюджет или сборы, режиссеры или продюссеры не критично, если совпадений немного.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Я о прокатных удостоверениях) Всего 2 дубликата, окец, можно удалить, но если ты рассмотришь подробнее, то заметишь, что Анализируй то это сиквел фильма Анализируй это. В обоих де Ниро снимается. Только я не знаю, почему в одно время они вышли у нас в прокат. Это при том, что первый фильм снят в 1999, а второй - в 2002. А еще откуда я знаю, рассмотрел ты дубли в названиях или нет, легко сделать вывод без кода...)

# %% [markdown]
# <div class="alert alert-info">Ну у них одинаковое удостоверение, они должны удалится, видимо произошла ошибка. Видимо строка "Анализируй то!" удалилась ранее.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v3 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Молодец) Видимо произошла ошибка)

# %% [markdown]
# #### Шаг 2.4. Изучите категориальные значения
#
# - Посмотрите, какая общая проблема встречается почти во всех категориальных столбцах;
# - Исправьте проблемные значения в поле `type`.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_1" aria-expanded="false" aria-controls="collapseHint_1">Подсказка</button>
#         </div>
#         <div id="collapseHint_1" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# В поле <code>type</code> есть несколько значений, у которых появился пробел в начале строки. Самый простой способ их «починить» -- использовать метод <a href="https://pandas.pydata.org/docs/reference/api/pandas.Series.str.strip.html#pandas.Series.str.strip">.str.strip</a>. Этот метод удаляет все пробелы, которые встречаются в начале и в конце строки. Применяют его таким образом:<br>
# <code>df['type'].str.strip()</code>
#             </div>
#         </div>
#     </div>
# </div>

# %%
def type_norm(typo):
    if typo[0] == ' ':
        typo = typo[1:]
    return typo


def category_norm(string):
    if (' - ') in string:
        string = string.split(' - ')
    elif ('-') in string:
        string = string.split('-')
    else:
        string = string.split(', ')
    return string


def genre_norm(string):
    if isinstance(string, float):
        pass
    else:
        string = string.split(',')
    return string


print(data['type'].unique())
data['type'] = data['type'].apply(type_norm)
print(data['type'].unique())

print(data['film_studio'].unique())
data['film_studio'] = data['film_studio'].apply(category_norm)
print(data['film_studio'].sort_values())

print(data['production_country'].unique())
data['production_country'] = data['production_country'].apply(category_norm)
print(data['production_country'].sort_values())

print(data['director'].unique())
data['director'] = data['director'].apply(category_norm)
print(data['director'].sort_values())

print(data['producer'].unique())
data['producer'] = data['producer'].apply(category_norm)
print(data['producer'].sort_values())

print(data['genres'].unique())
data['genres'] = data['genres'].apply(genre_norm)
print(data['genres'].sort_values())
# Out:
# ['Художественный' 'Анимационный' 'Прочие' 'Документальный'
#  'Научно-популярный' ' Художественный' ' Анимационный'
#  'Музыкально-развлекательный']
# ['Художественный' 'Анимационный' 'Прочие' 'Документальный'
#  'Научно-популярный' 'Музыкально-развлекательный']
# ['Тачстоун Пикчерз, Кобальт Пикчерз, Бикон Пикчерз, Тиг Продакшнз'
#  'Киностудия "Мосфильм"'
#  'Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Платт Продакшнз, Рилейтивити Медиа, Спайгласс Интертейнмент, Стилкин Филмз, Топ Кау Продакшнз'
#  ...
#  'Дэниел Гродник Продакшнз, Вандерфилм Медиа Корпорэйшн, Импринт Интертейнмент, Вор Хорс Интертейнмент, Пимиента '
#  'Никелодеон Анимейшн Студиос, Спин Мастер'
#  'Анимаккорд Лтд., ООО Студия "АНИМАККОРД"']
# 7290                                   [ АНО "Кинофорум"]
# 2767    [ Ауматик Интертейнмент, Блюмхаус Продакшнз и ...
# 5835    [ ЗАО "Кинокомпания ФаворитФильм" по заказу ОО...
# 4512    [ Константин Фильм, А Эр Ди Дегето Фильм, Дюне...
# ...

# %% [markdown]
# Проблемные значения в поле type были вызваны лишним пробелом перед названием типа фильма. Так же почти все категориальные столбцы хранили информацию в виде сплошных строк, например если режиссёров несколько, то их имена были склеины в одну строку и получить доступ к определённому не получится. Поэтому я пребразовал такие значения в массивы строк.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>  Тут было бы здорово тоже рассмотреть подробнее категориальные столбцы) Какая основная проблема встречается, кроме того, что ты перечислил?)

# %% [markdown]
# <div class="alert alert-info">Стобцы film_studio и production_country так же имеют проблемные места. В целом столбец film_studio стоило бы организовать по-другому, например "OOO" и прочее стоило вывести в отдельный столбец, а в этом оставить только названия, потому что эту мишуру впоследствии редактировать или получать как-то данные из неё в адекватном состоянии будет невозможно. Мужики просто сделали как могли... Столбец production_country обладает интересным свойством разделения стран по запятым, тире, тире с пробелами. Это тоже нужно обработать, что я в принципе и сделал изменив функцию category_norm. Встретились проблемные значения типа "К;анада", "СССР   ". Да, это можно обработать, но придётся писать более сложную функцию, либо удалять такие значения. В целом мы не ссылаемся на страну производства фильма, поэтому это не так критично, однако я бы рекомендовал структурировать ввод данных и не вводить данные с различным типом разделителей.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b>Хорошо, отлично) Но все-таки основаная проблема - это перечисление)

# %% [markdown]
# <div class="alert alert-info">Перечисление чего?
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v3 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> столбцы имеют очень много уникальных значений из-за того, что во всех этих полях идет перечисление одних и тех же значений

# %% [markdown]
# #### Шаг 2.5. Проверьте количественные значения
#
# - Проверьте, обнаружились ли в таких столбцах подозрительные данные. Как с такими данными лучше поступить?
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_budget" aria-expanded="false" aria-controls="collapseHint_budget">Подсказка</button>
#         </div>
#         <div id="collapseHint_budget" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Обратите внимание на описание столбца <code>budget</code>. Как этот столбец соотносится с двумя другими: <code>refundable_support</code> и <code>nonrefundable_support</code>?
#             </div>
#         </div>
#     </div>
# </div>

# %%
data.loc[data['budget'] == 0, ['budget']] = data['refundable_support'] + data['nonrefundable_support']

# %% [markdown]
# Столб бюджета это суммарный бюджет фильма. Соответственно если он равен нулю, но при этом значения в support не нули, значит мы должны добавить их в budget. Так же я обнаружил, что некоторые значения сборов слишком малы, однако как-то отбросить или изменить их невозможно. Например если пытаться заполнить эти проблемные значения ссылаясь на рейтинг (например рейтинг 9, сбор при этом слишком низок относительно бюджета, то мы его увеличиваем), однако на эти значения влияют слишком много факторов и в целом данные о бюджете и сборах проблемы и недостаточны.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Хорошечно)

# %% [markdown]
# #### Шаг 2.6. Добавьте новые столбцы

# %% [markdown]
# - Создайте столбец с информацией о годе проката. Выделите год из даты премьеры фильма.

# %%
data['year'] = pd.DatetimeIndex(data['show_start_date']).year

# %% [markdown]
# - Создайте два столбца: с именем и фамилией главного режиссёра и основным жанром фильма. В столбцы войдут первые значения из списка режиссёров и жанров соответственно.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_2" aria-expanded="false" aria-controls="collapseHint_2">Подсказка</button>
#         </div>
#         <div id="collapseHint_2" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Чтобы создать такие столбцы, лучше всего использовать собственную функцию. Эту функцию можно применить к двум столбцам сразу.
#             </div>
#         </div>
#     </div>
# </div>

# %%
def main_genre(genres):
    try:
        genres = genres[0]
    except TypeError:
        pass
    return genres


def main_director(director):
    try:
        director = director[0]
    except TypeError:
        pass
    return director


data['main_genre'] = data['genres']
data['main_genre'] = data['main_genre'].apply(main_genre)
data['main_director'] = data['director']
data['main_director'] = data['main_director'].apply(main_director)

# %% [markdown]
# Ранее я предобработал эти значения, теперь при помощи функции я просто выбрал первое имя и жанр.

# %% [markdown]
# - Посчитайте, какую долю от общего бюджета фильма составляет государственная поддержка.

# %%
data['part_of_budget'] = round(((data['refundable_support'] + data['nonrefundable_support']) / data['budget']) * 100)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Столбцы добалвены верно)

# %% [markdown]
# ### Шаг 3. Проведите исследовательский анализ данных

# %% [markdown]
# - Посмотрите, сколько фильмов выходило в прокат каждый год. Обратите внимание, что данные о прокате в кинотеатрах известны не для всех фильмов. Посчитайте, какую долю составляют фильмы с указанной информацией о прокате в кинотеатрах.

# %%
info = data.loc[~data['box_office'].isna()]
plot = info.pivot_table(index='year', values='title', aggfunc='count').plot(y='title', kind='bar', figsize=(15, 6), grid=True,
                                                                     title='Количество фильмов выходивших в определённый год')
plot.set_xlabel('Год')
plot.set_ylabel('Количество фильмов')
plot.legend(["Количество"], loc='upper left')
plt.show()

known_films = len(info) / len(data) * 100
print(known_films)
# Out:
# 42.31491416309013

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>  Отличный график! Только давай подпишем оси, легенду и заголовок (на русском)

# %% [markdown]
# <div class="alert alert-info">Что подразумевается под легендой? Параметр legend? xname? yname? метод legend?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Вопрос по поводу подписи графика остается открытым) Пол легедне отправляю полезную статью https://devpractice.ru/matplotlib-lesson-3-1-work-with-legend/

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v3 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>Доработано)

# %% [markdown]
# Я создал таблицу info исключив строки с пропусками в сборах. Полную информацию содержат 42% фильмов. Как мы можем заметить с каждым годом в прокат выходило больше фильмов. Само по себе это очевидно, кризис 2008 года, после него идёт восстановление и рост количества фильмов))) Также возможно что данные начали собирать в большем масштабе.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>  А изучим как доля с указанной информацией о прокате менялась по годам?

# %%
part_of_budget = []
for i in range(2010, 2020):
    part_of_budget.append([i, len(info.loc[info['year'] == i]) / len(data.loc[data['year'] == i])])
print(part_of_budget)
part_of_budget = pd.DataFrame(part_of_budget, columns=["Year", "Part"])
display(part_of_budget)
plot = part_of_budget.plot(x='Year', y='Part', kind='bar', figsize=(15, 9), grid=True, title='Доля фильмов с указанной информацией по годам')
plot.set_xlabel('Год')
plot.set_ylabel('Доля фильмов с указанной информацией относительно фильмов без информации')
plot.legend(["Доля"], loc='upper left')
plt.show()
# Out:
# [[2010, 0.10736196319018405], [2011, 0.17580645161290323], [2012, 0.21452702702702703], [2013, 0.29252782193958665], [2014, 0.34658385093167704], [2015, 0.6595744680851063], [2016, 0.642594859241126], [2017, 0.7069306930693069], [2018, 0.5392491467576792], [2019, 0.572354211663067]]
#    Year      Part
# 0  2010  0.107362
# 1  2011  0.175806
# 2  2012  0.214527
# 3  2013  0.292528
# 4  2014  0.346584
# 5  2015  0.659574
# 6  2016  0.642595
# 7  2017  0.706931
# 8  2018  0.539249
# 9  2019  0.572354

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Что скажешь?)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v3 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>ПОдпишем оси на графике? Про легенду тоже не забывай

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v4 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>Вот теперь идеально

# %% [markdown]
# - Изучите, как менялась динамика проката по годам. В каком году сумма сборов была минимальной? А максимальной?

# %%
plot = info.pivot_table(index='year', values='box_office', aggfunc='sum').plot(y='box_office', kind='bar', figsize=(15, 6),
                                                                        grid=True,
                                                                        title='Сборы за год')
plot.set_xlabel('Год')
plot.set_ylabel('Сборы фильмов')
plot.legend(["Сборы"], loc='upper left')
plt.show()
display(info.pivot_table(index='year', values='box_office', aggfunc='sum'))
# Out:
#         box_office
# year
# 2010  2.428654e+06
# 2011  1.410276e+07
# 2012  6.911073e+06
# 2013  2.979971e+07
# 2014  7.444952e+09
# 2015  3.949737e+10
# 2016  4.786611e+10
# 2017  4.856371e+10
# 2018  4.966836e+10
# 2019  4.842571e+10

# %% [markdown]
# Минимальная сумма сборов в 2014 году - наименьшее количество фильмов среди фильмов о которых есть информация по сборам. Всё логично и с остальными данными. Возможно в 2017 году было не так много фильмов, однако они получили высокий рейтинг и прибыль.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>  Тоже давай доделаем график) И выведем сводную тублицу? Иногда график может быть неинформативен

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Либо проект не сохранился, либо что-то непонятно тебе( Если есть вопросы, то пиши, не будем терять время

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v3 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Ага, молодец)

# %% [markdown]
# - С помощью сводной таблицы посчитайте среднюю и медианную сумму сборов для каждого года.

# %%
plot = info.pivot_table(index='year', values='box_office', aggfunc='mean').plot(y='box_office', kind='bar', figsize=(15, 6),
                                                                         grid=True,
                                                                         title='Средний сбор за год')
plot.set_xlabel('Год')
plot.set_ylabel('Сборы фильмов')
plot.legend(["Сборы в среднем"], loc='upper left')
plt.show()
display(info.pivot_table(index='year', values='box_office', aggfunc='mean'))

plot1 = info.pivot_table(index='year', values='box_office', aggfunc='median').plot(y='box_office', kind='bar', figsize=(15, 6),
                                                                           grid=True,
                                                                           title='Медианный сбор за год')

plot1.set_xlabel('Год')
plot1.set_ylabel('Сборы фильмов')
plot1.legend(["Медианные сборы"], loc='upper left')
plt.show()
display(info.pivot_table(index='year', values='box_office', aggfunc='median'))
# Out:
#         box_office
# year
# 2010  2.313004e+04
# 2011  1.293832e+05
# 2012  5.441790e+04
# 2013  1.619549e+05
# 2014  2.668442e+07
# 2015  8.494057e+07
# 2016  9.117353e+07
# 2017  1.360328e+08
# 2018  1.047856e+08
# 2019  9.136926e+07
#        box_office
# year
# 2010     1700.000
# 2011     3000.000
# 2012     5560.000
# 2013     3522.500
# 2014    18160.000
# 2015  4920933.000
# 2016  3915041.020
# 2017  9968340.000
# 2018  8911533.935
# 2019  4627798.345

# %% [markdown]
# Всё логично. Насчёт медианных значений 2014 и 2016 года возможно, что много значений по сборам было весьма маленьким, однако фильмы с хорошими сборами перекрыли их (отображено в таблице средних значений). 2014 год медианно отображает очень маленькое значение, возможно это связано с тем что в основном все проблемные данные по сборам были собраны именно в этот год.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>  Тоже выведем табличку, с посчитанными медианой и средней?) и доработаем графики

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Остается открытым вопрос

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v3 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>Идеально) Но для наглядности визуализацию можно оформить на одном полотне)

# %% [markdown]
# - Определите, влияет ли возрастное ограничение аудитории («6+», «12+», «16+», «18+» и т. д.) на сборы фильма в прокате в период с 2015 по 2019 год? Фильмы с каким возрастным ограничением собрали больше всего денег в прокате? Меняется ли картина в зависимости от года? Если да, предположите, с чем это может быть связано.

# %%
plot = info.loc[info['year'] > 2014].pivot_table(index='age_restriction', values='box_office', aggfunc='sum').plot(
    y='box_office', kind='bar', figsize=(15, 9),
    grid=True,
    title='Сборы фильмов в зависимости от возрасного ограничения по следующим годам: 2015-2019')
plot.set_xlabel('Возрастное ограничение')
plot.set_ylabel('Сборы фильмов')
plot.legend(["Суммарные сборы"], loc='upper left')
plt.show()
plot = info.loc[info['year'] > 2014].pivot_table(index='age_restriction', values='box_office', aggfunc='mean').plot(
    y='box_office', kind='bar', figsize=(15, 9),
    grid=True,
    title='Средние сборы фильмов в зависимости от возрасного ограничения по следующим годам: 2015-2019')
plot.set_xlabel('Возрастное ограничение')
plot.set_ylabel('Сборы фильмов')
plot.legend(["Средние сборы"], loc='upper left')
plt.show()
plot = info.loc[info['year'] > 2014].pivot_table(index='age_restriction', values='box_office', aggfunc='median').plot(
    y='box_office', kind='bar', figsize=(15, 9),
    grid=True,
    title='Медианные сборы фильмов в зависимости от возрасного ограничения по следующим годам: 2015-2019')
plot.set_xlabel('Возрастное ограничение')
plot.set_ylabel('Сборы фильмов')
plot.legend(["Медианные сборы"], loc='upper left')
plt.show()
for i in range(2015, 2020):
    plot = info.loc[info['year'] == i].pivot_table(index='age_restriction', values='box_office', aggfunc='sum').plot(
    y='box_office', kind='bar', figsize=(15, 9),
    grid=True,
    title=f'Сборы фильмов в зависимости от возрасного ограничения по следующим годам: {i}')
    plot.set_xlabel('Возрастное ограничение')
    plot.set_ylabel('Сборы фильмов')
    plot.legend(["Суммарные сборы"], loc='upper left')
    plt.show()
    plot = info.loc[info['year'] == i].pivot_table(index='age_restriction', values='box_office', aggfunc='mean').plot(
    y='box_office', kind='bar', figsize=(15, 9),
    grid=True,
    title=f'Средние сборы фильмов в зависимости от возрасного ограничения по следующим годам: {i}')
    plot.set_xlabel('Возрастное ограничение')
    plot.set_ylabel('Сборы фильмов')
    plot.legend(["Средние сборы"], loc='upper left')
    plt.show()
    plot = info.loc[info['year'] == i].pivot_table(index='age_restriction', values='box_office', aggfunc='median').plot(
    y='box_office', kind='bar', figsize=(15, 9),
    grid=True,
    title=f'Медианные сборы фильмов в зависимости от возрасного ограничения по следующим годам: {i}')
    plot.set_xlabel('Возрастное ограничение')
    plot.set_ylabel('Сборы фильмов')
    plot.legend(["Медианные сборы"], loc='upper left')
    plt.show()

# %% [markdown]
# В целом значения не сильно отличаются по годам. Скорее всего в определённые года было больше успешных картин для детей, например какой-нибудь мультик от Диснея, который хорошо выстрелил. Также можно сказать и про любой фильм. Однако самые прибыльные картины в категории 12 и 16 - самые популярные категории фильмов. Фильмы 0+ малопопулярны и в целом статистика по ним проблемна.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>  Хорошечно) А рассмотрим поведение средней или медианы?

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>Тоде самое(

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v3 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Молодец, все супер) только давай графики доработаем?)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v4 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Исправлено)

# %% [markdown]
# ### Шаг 4. Исследуйте фильмы, которые получили государственную поддержку
#
# На этом этапе нет конкретных инструкций и заданий — поищите интересные закономерности в данных. Посмотрите, сколько выделяют средств на поддержку кино. Проверьте, хорошо ли окупаются такие фильмы, какой у них рейтинг.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Упс, появились предпреждения. Для борьбы с ними могу посоветовать такой прием (импорт ставь в самом начале):
#
#     import warnings
#
#     warnings.filterwarnings("ignore")

# %%
warnings.filterwarnings("ignore")
info['supported_budget'] = info['refundable_support'] + info['nonrefundable_support']
info['supported_profit'] = info['box_office'] - info['budget']
plot = info.loc[info['budget'] > 0].pivot_table(
    index='year', values='supported_budget', aggfunc='sum').plot(y='supported_budget', kind='bar', figsize=(15, 9),
                                                                 grid=True, title='Спонсируемый бюджет')
plot.set_xlabel('Год')
plot.set_ylabel('Спонсируемый государством бюджет')
plot.legend(["Спонсируемый бюджет"], loc='upper left')
plt.show()

plot = info.loc[info['budget'] > 0].pivot_table(
    index='year', values='supported_profit', aggfunc='sum').plot(y='supported_profit', kind='bar', figsize=(15, 9),
                                                                 grid=True, title='Прибыль или убыль фильмов, спонсируемых государством по годам')
plot.set_xlabel('Год')
plot.set_ylabel('Суммарная прибыль фильмов')
plot.legend(["Прибыль"], loc='upper left')
plt.show()

plot = info.loc[info['budget'] > 0].pivot_table(
    index='year', values='box_office', aggfunc='sum').plot(y='box_office', kind='bar', figsize=(15, 9),
                                                           grid=True, title='Сборы фильмов, спонсируемых государством по годам')
plot.set_xlabel('Год')
plot.set_ylabel('Суммарные сборы фильмов')
plot.legend(["Суммарные сборы"], loc='upper left')
plt.show()

plot = info.loc[info['budget'] > 0].pivot_table(index='year', values='ratings', aggfunc='mean').plot(y='ratings', kind='bar', figsize=(15, 9),
                                                           grid=True, title='Средний рейдинг фильмов спонсируемых государством')
plot.set_xlabel('Год')
plot.set_ylabel('Средний рейтинг')
plot.legend(["Рейтинг"], loc='upper left')
plt.show()
agg_func_math = {
    'budget': ['sum'],
    'box_office': ['sum'],
    'supported_profit': ['sum'],
    'main_genre': ['first']
}
directors = info.loc[info['supported_budget'] > 0].groupby('main_director').agg(agg_func_math)
display(directors.sort_values(by=('supported_profit', 'sum')))
# Out:
#                                              budget    box_office  \
#                                                 sum           sum
# main_director
# О.Степченко                            2.305074e+09  3.335971e+08
# А.Михалков (псевдоним А.Кончаловский)  7.799420e+08  5.424320e+07
# А.Учитель                              1.032906e+09  5.117755e+08
# Р.Давлетьяров                          7.704302e+08  2.992629e+08
# А.Мельник                              5.000000e+08  7.257832e+07
# ...                                             ...           ...
# О.Трофим                               1.485852e+08  1.445732e+09
# Д.Дьяченко                             7.806953e+08  2.404899e+09
# А.Сидоров                              5.637847e+08  2.271754e+09
# А.Мегердичев                           5.901922e+08  2.779686e+09
# К.Шипенко                              7.049307e+08  3.827772e+09
#
#                                       supported_profit   main_genre
# ...

# %% [markdown]
# Активно поддерживать киноиндустрию начали с 2015 года. Однако успешные года - 2017 и 2018, они принесли значительную прибыль, в то время как в остальные года релизы в среднем провалились. Несмотря на это средний рейтин у фильмов находится от 5.5 до 7. Возможно рейтинг был накручен, либо фильмы стали более популярны с их появлением в интернете и как-таковых сборов в кинотеатрах у них не было.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>  Исследуем режиссеров? Самых спонсируемых? Окупаемость их фильмов? Жанры?

# %% [markdown]
# <div class="alert alert-info">Через групбай? Если да, то в каком формате его выводить?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v3 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Да, можно через групбай) Можем посчитать сумму, которую каждый режиссер потратил на кино и сколько заработал?

# %% [markdown]
# <div class="alert alert-info">Вывел отсортированный по прибыли(убыли) датафрейм содержащий информацию о бюджете, сборах, прибыли и основного жанра по режиссёрам. Интересно наблюдать количество убыльных проектов...
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v4 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>Хорошо, только вывод лучше сделать подробнее

# %% [markdown]
# ### Шаг 5. Напишите общий вывод

# %% [markdown]
# Я провёл обработку данных, изменил необходимые столбцы и подправил типы данных. В данном проекте это было не сложно, т.к. зачастую все данные были в норме. Однако присутсвует очень грубая ошибка в столбце с прибылью и бюджетом фильма. Нет бюджетов иностранных фильмов, а столбец с прибылью содержит аномальные значения. Эти столбцы трудно обработать, т.к. из-за отсутствия столбца с бюджетом мы не можем выстроить хоть какую-то корелляцию бюджета и рейтинга фильма для корректировки значений прибыли. То есть данные нуждаются в серьёзной доработке по этим двум столбцам. Также было замечено, что самая популярная категория фильмов - 16+. Отечественные фильмы с господдержкой зачастую не приносят прибыли (выходят в ноль), самый прибыльный для них год - 2017, а убыльный - 2019. Однако не смотря на это рейтинг фильмов находится на отметке более 5, что в моём понимании должно отражатся в худшем случае - выход в ноль, а лучшем случае сборы должны приносить хорошую прибыль. Однако этого не случается. Возможно дело в накрутке рейтинга, либо эти фильмы получили больший успех при просмотре их в интернете на различных платформах. После анализа информации о режиссерах, можно увидеть большое количество убыльных проектов, что грустно.
#
# Рекомендации: хранить информацию по одному принципу (использовать одинаковый тип данных, одинаковые разделители), либо изначально хранить данные в массивах.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>  исправим замечания и доработаем вывод)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Проект либо не сохранился, либо у тебя возникли сложности? Красные комментарии не отработаны:( Если что-то непонятно, то задавай вопросы.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v3 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> Не забывай, что замечания по оформлению графиков относятся ко всему проекту)

# %% [markdown]
# <div class="alert alert-info">Вроде всё сделал. Я отправлял проект постепенно, поэтому не всё делал сразу.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v4 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Вывод отражает проделанную работу!

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту ревьювера**:
# Нияз, спасибо за  проект! Ты приложил много усилий, чтобы довести его до конца, проделана огромная работа, и это видно невооруженным глазом, ты большой молодец!
#
# **Отмечу положительные моменты**:
#
#     1. Все разложено по полочкам, всегда понятен ход твоих мыслей, приятно смотреть
#
#     2. Отличные визуализации
#
#     3. На разных шагах проекта ты предлагал очень интересные решения и методы для их реализации. Хорошая работа!
#
#
# **На что стоит обратить внимание**:
#
#     1. Замечания в предобработке
#
#     2. Оформление графиков
#
#     3. Не рассмотрена доля фильмов по годам с указанной информаицей
#
#
# **Удачи и жду твой проект на повторное ревью!**

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту ревьювера v2**:
# Нияз, продолжаем работу)

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту ревьювера v3**:
# Нияз, исправим оставшиеся замечания и проект будет зачтен)

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту ревьювера v4**:
# Нияз, ошибки исправлены, проект принят, поздравляю тебя! Успешной учебы и еще увидимся в Практикуме!
